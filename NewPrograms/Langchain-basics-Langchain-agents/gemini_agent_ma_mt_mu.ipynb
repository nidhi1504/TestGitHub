# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhi1504/TestGitHub/blob/main/NewPrograms/Langchain-basics-Langchain-agents/gemini_agent_ma_mt_mu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
============================= test session starts ==============================
platform linux -- Python 3.11.6, pytest-8.2.0, pluggy-1.5.0
rootdir: /ci/workspace/shopfront-e2e
plugins: playwright-0.5.1, xdist-3.6.1
collected 10 items

Run ID: nightly-2026-08-01T02:00:11Z
Environment: ci-staging
Commit: 4f9ac21

tests/test_auth.py::test_login_valid_credentials PASSED                  [ 10%]
tests/test_auth.py::test_login_invalid_password PASSED                   [ 20%]
tests/test_cart.py::test_add_to_cart PASSED                              [ 30%]
tests/test_cart.py::test_remove_from_cart PASSED                         [ 40%]
tests/test_checkout.py::test_checkout_total_calculation FAILED           [ 50%]
tests/test_checkout.py::test_payment_gateway_timeout FAILED             [ 60%]
tests/test_search.py::test_search_returns_results FAILED                 [ 70%]
tests/test_profile.py::test_user_profile_update FAILED                   [ 80%]
tests/test_orders.py::test_order_history_loads PASSED                    [ 90%]
tests/test_inventory.py::test_inventory_sync PASSED                      [100%]

=================================== FAILURES ===================================
_____________________ test_checkout_total_calculation __________________________

    def test_checkout_total_calculation():
        cart = add_items([("Wireless Mouse", 100.00)])
        summary = checkout(cart, tax_rate=0.08)
>       assert summary.total == 108.00
E       assert 100.00 == 108.00
E        +  where 100.00 = <OrderSummary subtotal=100.00 tax=0.00 total=100.00>.total

tests/test_checkout.py:24: AssertionError
------------------------------ Captured log --------------------------------
INFO  checkout.service: computing summary subtotal=100.00 tax_rate=0.08
WARN  checkout.service: tax component resolved to 0.00 (expected 8.00)

_____________________ test_payment_gateway_timeout _____________________________

    def test_payment_gateway_timeout():
        order = place_order(sample_cart())
>       result = pay(order, gateway="sandbox")
E       requests.exceptions.ConnectTimeout: HTTPSConnectionPool(host='pay-sandbox.internal', port=443):
E       Max retries exceeded (Caused by ConnectTimeoutError: connection to pay-sandbox.internal timed out after 30.0s)

tests/test_checkout.py:41: ConnectTimeout
------------------------------ Captured log --------------------------------
INFO  payment.client: POST https://pay-sandbox.internal/charge
ERROR payment.client: gateway returned 503 Service Unavailable (attempt 1/3)
ERROR payment.client: gateway returned 503 Service Unavailable (attempt 2/3)
ERROR payment.client: connection timed out (attempt 3/3)

_____________________ test_search_returns_results ______________________________

    def test_search_returns_results():
        page.goto("/search?q=backpack")
>       page.wait_for_selector(".results-grid .result-item", timeout=5000)
E       playwright._impl._errors.TimeoutError: Timeout 5000ms exceeded.
E       Waiting for selector ".results-grid .result-item" to be visible

tests/test_search.py:17: TimeoutError
------------------------------ Captured log --------------------------------
INFO  search.page: navigated to /search?q=backpack
INFO  search.page: results-grid rendered after 5120ms (over budget)

_____________________ test_user_profile_update _________________________________

    def test_user_profile_update():
        user = get_user("qa-user-01")
>       update_profile(user, {"display_name": "QA User"})
E       psycopg2.OperationalError: could not connect to server: Connection refused
E           Is the server running on host "db-staging.internal" (10.4.2.9) and accepting
E           TCP/IP connections on port 5432?

tests/test_profile.py:29: OperationalError
------------------------------ Captured log --------------------------------
ERROR db.pool: connection to db-staging.internal:5432 refused
ERROR db.pool: all 3 pool connections unavailable

=========================== short test summary info ============================
FAILED tests/test_checkout.py::test_checkout_total_calculation
FAILED tests/test_checkout.py::test_payment_gateway_timeout
FAILED tests/test_search.py::test_search_returns_results
FAILED tests/test_profile.py::test_user_profile_update
======================== 6 passed, 4 failed in 92.41s =========================
# Out:
#   File "/tmp/ipykernel_2048/1731261917.py", line 7
#     Run ID: nightly-2026-08-01T02:00:11Z
#                          ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
# !pip install -U langchain langchain-google-genai langchain-chroma chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import os
from datetime import datetime

from langchain.agents import create_agent
from langchain.tools import tool
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_core.messages import HumanMessage, AIMessage

# %%
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2048/1571651384.py in <cell line: 0>()
#       3
#       4 #API_KEY = put the new api key here created latest
# ----> 5 api_key = userdata.get("GOOGLE_API_KEY")
#       6 client = genai.Client(api_key=api_key)
#
# /usr/local/lib/python3.13/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret GOOGLE_API_KEY does not exist.

# %%
# =========================
# 1. API KEY
# =========================

#os.environ["GOOGLE_API_KEY"] = "YOUR_GEMINI_API_KEY"

# =========================
# 2. LLM
# =========================

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.3,
    api_key=api_key
)

# =========================
# 3. VECTOR DATABASE - CHROMADB
# =========================

docs = [
    Document(page_content="Machine Learning is a branch of AI that learns patterns from data."),
    Document(page_content="Deep Learning uses neural networks with many layers."),
    Document(page_content="RAG means Retrieval Augmented Generation. It uses vector databases to retrieve relevant knowledge."),
    Document(page_content="LangChain is used to build LLM applications with prompts, chains, agents, tools, memory and retrieval."),
    Document(page_content="Agentic AI means AI systems that can plan, use tools, remember context, and perform tasks.")
]

embeddings = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001",
    api_key=api_key
)

vector_db = Chroma.from_documents(
    documents=docs,
    embedding=embeddings,
    collection_name="knowledge_base",
    persist_directory="./chroma_multi_agent_db"
)

retriever = vector_db.as_retriever(search_kwargs={"k": 2})

# %%
# =========================
# 4. TOOLS
# =========================

@tool
def get_current_time() -> str:
    """Get the current date and time."""
    return str(datetime.now())


@tool
def calculator(expression: str) -> str:
    """Calculate a simple mathematical expression. Example: 20*5 + 10"""
    try:
        allowed_chars = "0123456789+-*/(). "
        if not all(ch in allowed_chars for ch in expression):
            return "Invalid expression. Only basic arithmetic is allowed."

        result = eval(expression)
        return str(result)

    except Exception as e:
        return f"Calculation error: {e}"


@tool
def search_knowledge_base(query: str) -> str:
    """Search the ChromaDB vector database for useful knowledge."""
    results = retriever.invoke(query)

    if not results:
        return "No relevant knowledge found."

    return "\n".join([doc.page_content for doc in results])


@tool
def save_output_to_file(content: str) -> str:
    """Save final output to a text file."""
    file_name = "agent_output.txt"

    with open(file_name, "w", encoding="utf-8") as f:
        f.write(content)

    return f"Output saved to {file_name}"


tools = [
    get_current_time,
    calculator,
    search_knowledge_base,
    save_output_to_file
]

# %%
# =========================
# 5. MULTIPLE AGENTS
# =========================

research_agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt="""
    You are a Research Agent.
    Your job is to search knowledge, explain concepts, and answer factual questions.
    Use search_knowledge_base when needed.
    Answer in simple English.
    """
)

writing_agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt="""
    You are a Writing Agent.
    Your job is to write blogs, summaries, emails, notes, and explanations.
    Use simple English.
    Use save_output_to_file if the user asks to save.
    """
)

math_agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt="""
    You are a Math Agent.
    Your job is to solve arithmetic and calculation-related questions.
    Use calculator tool whenever calculation is needed.
    Show the final answer clearly.
    """
)

general_agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt="""
    You are a General Assistant Agent.
    Answer general questions clearly and simply.
    Use tools when useful.
    """
)

# %%
# =========================
# 6. MULTI-USER MEMORY
# =========================

user_memory = {
    "user1": [],
    "user2": [],
    "user3": []
}

# =========================
# 7. ROUTER AGENT FUNCTION
# =========================

def choose_agent(task: str):
    task_lower = task.lower()

    if any(word in task_lower for word in ["calculate", "sum", "multiply", "divide", "+", "-", "*", "/"]):
        return math_agent, "Math Agent"

    elif any(word in task_lower for word in ["write", "blog", "email", "summary", "article", "notes"]):
        return writing_agent, "Writing Agent"

    elif any(word in task_lower for word in ["what is", "explain", "research", "rag", "langchain", "machine learning", "agentic"]):
        return research_agent, "Research Agent"

    else:
        return general_agent, "General Agent"

# %%
# =========================
# 8. MAIN MULTI-USER CHAT FUNCTION
# =========================

def ask_multi_agent(user_id: str, user_input: str):
    if user_id not in user_memory:
        user_memory[user_id] = []

    selected_agent, agent_name = choose_agent(user_input)

    memory_text = ""

    for msg in user_memory[user_id]:
        if isinstance(msg, HumanMessage):
            memory_text += f"User: {msg.content}\n"
        elif isinstance(msg, AIMessage):
            memory_text += f"Assistant: {msg.content}\n"

    final_input = f"""
    Previous conversation with this user:
    {memory_text}

    Current user request:
    {user_input}
    """

    response = selected_agent.invoke({
        "messages": [
            {
                "role": "user",
                "content": final_input
            }
        ]
    })

    answer = response["messages"][-1].content

    user_memory[user_id].append(HumanMessage(content=user_input))
    user_memory[user_id].append(AIMessage(content=answer))

    return agent_name, answer

# %%
# =========================
# 9. INTERACTIVE MULTI-USER LOOP
# =========================

print("Multi-User Multi-Agent System Started")
print("Users: user1, user2, user3")
print("Type 'exit' to stop\n")

while True:
    user_id = input("Enter user id: ")

    if user_id.lower() == "exit":
        break

    user_question = input("Enter task/question: ")

    if user_question.lower() == "exit":
        break

    agent_used, answer = ask_multi_agent(user_id, user_question)

    print("\nAgent Used:", agent_used)
    print("Answer:\n", answer)
    print("-" * 80)
