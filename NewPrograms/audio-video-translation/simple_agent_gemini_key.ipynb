# %%
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)

# %%
#client = genai.Client(api_key=api_key)

# Create a chat session
chat = client.chats.create(
    model="gemini-3.5-flash"
)

print("Agent started. Type 'exit' to quit.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break

    try:
        response = chat.send_message(user_input)

        print("\nAgent:")
        print(response.text)
        print()

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Agent started. Type 'exit' to quit.
#
# You: bug.excel
#
# Agent:
# It sounds like you are dealing with a bug or an unexpected issue in Microsoft Excel!
#
# To help you fix it, I need a little more information. **Could you describe what is happening?**
#
# Please reply with:
# 1. **What are you trying to do, and what is happening instead?** (e.g., "Excel freezes when I copy paste," "My formula shows `#VALUE!`," or "The gridlines disappeared.")
# 2. **Are you getting an error message?** (If so, what does it say?)
# 3. **What version of Excel are you using?** (e.g., Office 365, Excel 2019, Excel for Mac, Excel Web).
#
# ---
#
# In the meantime, here are some of the **most common Excel bugs** and how to quickly solve them:
#
# ### 1. Formulas are showing as text (e.g., `=SUM(A1:A10)` is visible instead of the result)
# * **The Fix:** The cell is likely formatted as "Text."
#   1. Select the cell.
#   2. Change the format in the Home tab from **Text** to **General**.
#   3. Double-click inside the cell and press **Enter** to recalculate.
#   4. Also, check if **Show Formulas** is turned on (Press `Ctrl` + `~` to toggle it off).
#
# ### 2. Excel formulas are not updating/calculating automatically
# * **The Fix:** Your calculation options might have been set to manual.
#   1. Go to the **Formulas** tab.
#   2. Click **Calculation Options**.
#   3. Select **Automatic**.
#
# ### 3. Excel keeps crashing, freezing, or saying "Not Responding"
# * **The Fix (Disable Add-ins):** Often, third-party add-ins cause Excel to crash.
#   1. Open Excel in **Safe Mode** (Hold the `Ctrl` key while clicking the Excel icon to open it).
#   2. If it works fine in Safe Mode, go to **File > Options > Add-ins**.
#   3. At the bottom, select **COM Add-ins** and click **Go**.
#   4. Uncheck all add-ins, restart Excel normally, and turn them back on one by one to find the culprit.
#
# ### 4. Dates are showing up as random numbers (e.g., `45181`)
# * **The Fix:** Excel stores dates as serial numbers.
#   1. Select the cells.
#   2. Go to the Home tab and change the dropdown format from **General** to **Short Date**.
#
# ### 5. Green triangles in the corner of cells
# * **The Fix:** This is an error indicator (usually "Number Stored as Text").
#   1. Highlight the affected cells.
#   2. Click the yellow warning icon that appears next to them.
#   3. Click **Convert to Number**.
#
# **Tell me what is going wrong with your spreadsheet, and we will get it sorted out!**
#
# You: bug format in excel
#
# Agent:
# It sounds like you might mean one of two things by **"bug format"**:
#
# 1. **You are experiencing a bug with formatting in Excel** (e.g., numbers, dates, or text are formatting incorrectly).
# 2. **You want to create a "Bug Tracker" format/template in Excel** to track software bugs and issues.
#
# Here are solutions for **both** scenarios.
#
# ---
#
# ### Scenario 1: You are experiencing a Formatting Bug in Excel
# Here are the most common formatting "bugs" in Excel and how to fix them:
#
# #### A. The "Dates turned into 5-digit numbers" Bug (e.g., `12/25/2023` becomes `45285`)
# * **Why it happens:** Excel stores dates as serial numbers. Sometimes Excel loses the date formatting.
# * **The Fix:** Select the cells, go to the **Home** tab, click the number format dropdown (usually says "General"), and select **Short Date**.
#
# #### B. The "Disappearing Leading Zeros" Bug (e.g., `01234` becomes `1234`)
# * **Why it happens:** Excel automatically formats numbers as integers and drops the `0`.
# * **The Fix:**
#   1. Select the cells.
#   2. Press `Ctrl + 1` to open the Format Cells menu.
#   3. Go to **Custom** and type `00000` (five zeros) in the "Type" box to force 5-digit zip codes, or format the cells as **Text** *before* typing the number.
#
# #### C. The "Scientific Notation" Bug (e.g., large ID numbers show as `1.23E+11`)
# * **Why it happens:** Excel shortens numbers longer than 11 digits.
# * **The Fix:**
#   1. Select the cells, press `Ctrl + 1`.
#   2. Select **Number** and set "Decimal places" to `0`.
#   3. If the number is longer than 15 digits (like credit card numbers), you *must* format the cells as **Text** before typing them, or Excel will turn the remaining digits to `0`.
#
# ---
#
# ### Scenario 2: You want to format a "Bug Tracker" template
# If you are trying to design an Excel sheet to track software bugs, here is the best way to format it.
#
# #### 1. Setup these Column Headers:
# | Bug ID | Title/Issue | Description | Priority | Status | Assigned To | Date Reported | Date Resolved |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | BUG-001 | Login button not working | Users cannot click login... | High | In Progress | Sarah | 2023-10-24 | |
# | BUG-002 | Typo in footer | "Contact Us" is spelled wrong | Low | Resolved | Alex | 2023-10-23 | 2023-10-24 |
#
# #### 2. Apply Conditional Formatting (Color Coding Statuses):
# To make your bug tracker easy to read, color-code the "Priority" or "Status" columns:
# 1. Highlight your **Status** column (e.g., Column E).
# 2. Go to **Home > Conditional Formatting > Highlight Cells Rules > Text that Contains...**
# 3. Type **"Resolved"** and format it with **Light Green Fill**.
# 4. Repeat the steps for **"In Progress"** (Yellow) and **"New"** (Red).
#
# #### 3. Use Data Validation for Status/Priority (Dropdown Menus):
# To prevent typos:
# 1. Select the cells in the **Status** column.
# 2. Go to the **Data** tab > **Data Validation**.
# 3. Under *Allow*, select **List**.
# 4. Under *Source*, type: `New, In Progress, Resolved, Closed` (separated by commas).
# 5. Click **OK**. Now you have a dropdown menu.
#
# ***
#
# **Which of these two were you looking for?** If it is a different formatting issue, describe it and I will help you fix it!
#
# You: in table format
#
# Agent:
# Here is the information presented in clean, easy-to-read table formats.
#
# ---
#
# ### Table 1: Common Excel Formatting "Bugs" & Quick Fixes
#
# | The Formatting "Bug" | Why It Happens | Step-by-Step Fix |
# | :--- | :--- | :--- |
# | **Dates turn into 5-digit numbers** <br>*(e.g., 12/25/2023 becomes `45285`)* | Excel stores dates as sequential numbers. It lost the date formatting. | 1. Select the cell(s).<br>2. Go to **Home > Number Format** dropdown.<br>3. Select **Short Date**. |
# | **Leading zeros disappear** <br>*(e.g., `00123` becomes `123`)* | Excel automatically treats digits as standard numbers and drops leading zeros. | **Option A:** Type an apostrophe (`'`) before the number (e.g., `'00123`).<br>**Option B:** Select cells -> Press `Ctrl + 1` -> Select **Text** -> Click OK. |
# | **Large numbers show "E+"** <br>*(e.g., `1.23E+11` instead of `123456789012`)* | Excel uses Scientific Notation for numbers longer than 11 digits. | 1. Select cells -> Press `Ctrl + 1`.<br>2. Select **Number** (set Decimal places to `0`).<br>3. Click OK. |
# | **Formulas show as text** <br>*(e.g., `=SUM(A1:A5)` is visible instead of the answer)* | The cell is formatted as Text, or "Show Formulas" is turned on. | 1. Change cell format to **General**.<br>2. Double-click inside the cell and press **Enter**.<br>3. If all formulas are showing, press `Ctrl + ~` to toggle them off. |
#
# ---
#
# ### Table 2: Recommended "Bug Tracker" Table Format (Template)
#
# If you are setting up a sheet to track software/QA bugs, set up your columns with these data types and dropdowns:
#
# | Column Header (Row 1) | Data Type / Format | Dropdown List (Data Validation) | Example Entry |
# | :--- | :--- | :--- | :--- |
# | **Bug ID** | Custom: `"BUG-"000` | *None* | `BUG-001` |
# | **Bug Title** | Text | *None* | `Login button unresponsive` |
# | **Description** | Text (Wrap Text enabled) | *None* | `Clicking login does not redirect user.` |
# | **Environment** | Text | `Production, Staging, QA` | `Staging` |
# | **Severity** | Text | `Critical, High, Medium, Low` | `Critical` |
# | **Status** | Text | `New, In Progress, QA, Closed` | `In Progress` |
# | **Assigned To** | Text | *List of Team Members* | `Sarah Connor` |
# | **Date Reported** | Date (`YYYY-MM-DD`) | *None* | `2023-10-24` |
# | **Date Resolved** | Date (`YYYY-MM-DD`) | *None* | `2023-10-26` |
#
# ---
#
# ### 💡 Pro Tip: Turn your data into an official Excel Table
# To make your bug list sortable, searchable, and clean:
# 1. Highlight your data (including headers).
# 2. Press **`Ctrl + T`** (Windows) or **`Cmd + T`** (Mac).
# 3. Check the box **"My table has headers"** and click **OK**.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_510/3907916816.py in <cell line: 0>()
#       9
#      10 while True:
# ---> 11     user_input = input("You: ")
#      12
#      13     if user_input.lower() in ["exit", "quit"]:
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#client = genai.Client(api_key=api_key)

# Create a chat session
chat = client.chats.create(
    model="gemini-3.5-flash"
)

print("Agent started. Type 'exit' to quit.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break

    try:
        response = chat.send_message(user_input)

        print("\nAgent:")
        print(response.text)
        print()

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Agent started. Type 'exit' to quit.

# %%
import pandas as pd

# Data structure mapping each failing test case with its details
failures_data = [
    {
        "Test Case": "test_checkout_total_calculation",
        "File": "tests/test_checkout.py",
        "Error Type": "AssertionError",
        "Description": "Expected 108.00, got 100.00 (tax computed to 0.00 instead of 8.00).",
        "Category": "Application Logic Bug (Tax calculation failed)"
    },
    {
        "Test Case": "test_payment_gateway_timeout",
        "File": "tests/test_checkout.py",
        "Error Type": "ConnectTimeout",
        "Description": "HTTPS connection to pay-sandbox.internal timed out after 30 seconds after returning 503 errors.",
        "Category": "Infrastructure / Integration (External payment service down)"
    },
    {
        "Test Case": "test_search_returns_results",
        "File": "tests/test_search.py",
        "Error Type": "TimeoutError",
        "Description": "Waiting for selector '.results-grid .result-item' exceeded 5000ms limit (took 5120ms).",
        "Category": "Performance / UI Flakiness (Exceeded rendering budget)"
    },
    {
        "Test Case": "test_user_profile_update",
        "File": "tests/test_profile.py",
        "Error Type": "OperationalError",
        "Description": "Database connection to db-staging.internal:5432 refused.",
        "Category": "Infrastructure (Database server is offline or unreachable)"
    }
]

# Display structured report using a DataFrame
df_failures = pd.DataFrame(failures_data)
display(df_failures)

# %%
# Export the failures DataFrame to an Excel file
import pandas as pd
from google.colab import files

file_path = '/content/test_failures_report.xlsx'
df_failures.to_excel(file_path, index=False)

# Provide a download link for Colab users
files.download(file_path)

# %% [markdown]
# ### 🛠️ Working Repository Setup
# Follow the instructions below to create a GitHub repository, initialize it here, and upload your triage reports and python notebooks.

# %%
#@title GitHub Repository Initialization
import os

# Configure your repository settings here:
GITHUB_USERNAME = "your-github-username" #@param {type:"string"}
GITHUB_REPO_NAME = "shopfront-triage-reports" #@param {type:"string"}
GITHUB_EMAIL = "your-email@example.com" #@param {type:"string"}
GITHUB_TOKEN = "" #@param {type:"string"}

# Configure global git configs
# !git config --global user.name "{GITHUB_USERNAME}"
# !git config --global user.email "{GITHUB_EMAIL}"

# Create local repository directory and move artifacts there
# !mkdir -p /content/{GITHUB_REPO_NAME}
# !cp -f /content/test_failures_report.xlsx /content/{GITHUB_REPO_NAME}/ 2>/dev/null || true

# Initialize and add files
# %cd /content/{GITHUB_REPO_NAME}
# !git init
# !echo "# Shopfront End-to-End Triage Reports" > README.md
# !git add README.md test_failures_report.xlsx 2>/dev/null || true
# !git commit -m "Initial commit: add automated triage reports"

# Note: To push to your remote repository, execute:
# !git remote add origin https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git
# !git branch -M main
# !git push -u origin main

# %%
# !pip -q install -U groq reportlab nbformat
